# %%
# # Import packages
import numpy as np
import pandas as pd
#import pandas_datareader as pddr
import datetime as dt
import os
# import matplotlib.pyplot as plt

# from bokeh.io import output_file
from bokeh.plotting import figure, show
from bokeh.io import output_file
from bokeh.models import ColumnDataSource, Title, Legend, HoverTool
from bokeh.models.tickers import SingleIntervalTicker
# from usempl_streaks import get_usempl_data, usempl_streaks
from usempl_plots.get_payems import get_payems_data

# %%
start_date = "min"
end_date = "max"
download_from_internet = True
fig_title_str = (
    "US employment streaks: consecutive positive monthly gains and " +
    "cumulative employment gains, 1939 to 2024"
)
html_show = True

# %%
# Create data and images directory paths
cur_path = "/Users/richardevans/Docs/Economics/OSE/usempl-plots/usempl_plots"
image_dir = os.path.join(cur_path, "images")
data_dir = os.path.join(cur_path, "data")

# Get the employment data
if start_date == "min":
    beg_date_str = "1939-01-01"
else:
    try:
        beg_date_test = dt.datetime.strptime(start_date, "%Y-%m-%d")
    except:
        err_msg = (
            "Error get_payems.py: start_date input must be either a "
            + "date string in 'YYYY-mm-dd' format or 'min'."
        )
        raise ValueError(err_msg)
    beg_date_str = start_date

if end_date == "max":
    end_date_str = "today"
else:
    try:
        end_date_test = dt.datetime.strptime(end_date, "%Y-%m-%d")
    except:
        err_msg = (
            "Error get_payems.py: end_date input must be either a "
            + "date string in 'YYYY-mm-dd' format or 'max'."
        )
        raise ValueError(err_msg)
    end_date_str = end_date

if end_date_str == "today":
    download_date = dt.datetime.today()
else:
    download_date = dt.datetime.strptime(end_date_str, "%Y-%m-%d")
download_date_str = download_date.strftime("%Y-%m-%d")
if download_from_internet:
    usempl_df, beg_date_str2, end_date_str2 = get_payems_data(
        beg_date_str=beg_date_str,
        end_date_str=end_date_str,
        file_path=None,
    )
    print(
        "PAYEMS data downloaded on "
        + download_date_str
        + " and has most recent PAYEMS data month of "
        + end_date_str2
        + "."
    )
else:
    usempl_df, beg_date_str2, end_date_str2 = get_payems_data(
        beg_date_str=beg_date_str,
        end_date_str=end_date_str,
        file_path=os.path.join(
            data_dir, "usempl_" + end_date_str + ".csv"
        ),
    )
    print(
        "PAYEMS data loaded from memory on "
        + download_date_str
        + " and has most recent PAYEMS data month of "
        + end_date_str2
        + "."
    )
# Out:
# Beginning date of U.S. employment series is 1939-01-01
# End date of U.S. employment series is 2024-03-01
# PAYEMS data downloaded on 2024-04-28 and has most recent PAYEMS data month of 2024-03-01.

# %%
usempl_df
# Out:
#            Date     PAYEMS  BLS_annual  diff_monthly   diff_yoy  \
# 0    1939-01-01   29923000         NaN           NaN        NaN
# 1    1939-02-01   30100000         NaN      177000.0        NaN
# 2    1939-03-01   30280000         NaN      180000.0        NaN
# 3    1939-04-01   30094000         NaN     -186000.0        NaN
# 4    1939-05-01   30299000         NaN      205000.0        NaN
# ...         ...        ...         ...           ...        ...
# 1018 2023-11-01  157014000         NaN      182000.0  2859000.0
# 1019 2023-12-01  157304000         NaN      290000.0  3013000.0
# 1020 2024-01-01  157560000         NaN      256000.0  2787000.0
# 1021 2024-02-01  157830000         NaN      270000.0  2770000.0
# 1022 2024-03-01  158133000         NaN      303000.0  2927000.0
#
#                   Source
# 0     BLS monthly series
# 1     BLS monthly series
# 2     BLS monthly series
# 3     BLS monthly series
# 4     BLS monthly series
# ...                  ...
# 1018  BLS monthly series
# 1019  BLS monthly series
# 1020  BLS monthly series
# 1021  BLS monthly series
# 1022  BLS monthly series
#
# [1023 rows x 6 columns]

# %%
start_date = 'min'
end_date = 'max'
recession_bars = True
download = True
fig_title_str = "Time Series of US Monthly Nonfarm Payroll Employment (PAYEMS)"
html_show = True

# %%
# Create data and images directory as well as recession data path
cur_path = "/Users/richardevans/Docs/Economics/OSE/usempl-plots/usempl_plots"
image_dir = os.path.join(cur_path, "images")
data_dir = os.path.join(cur_path, "data")
recession_data_path = os.path.join(data_dir, 'recession_data.csv')

# %%
# Get the employment data
if start_date == 'min':
    beg_date_str = "1919-01-01"
else:
    try:
        beg_date_test = dt.datetime.strptime(start_date, "%Y-%m-%d")
    except:
        err_msg = (
            "Error get_payems.py: start_date input must be either a " +
            "date string in 'YYYY-mm-dd' format or 'min'."
        )
        raise ValueError(err_msg)
    beg_date_str = start_date

if end_date == 'max':
    end_date_str = "today"
else:
    try:
        end_date_test = dt.datetime.strptime(end_date, "%Y-%m-%d")
    except:
        err_msg = (
            "Error get_payems.py: end_date input must be either a " +
            "date string in 'YYYY-mm-dd' format or 'max'."
        )
        raise ValueError(err_msg)
    end_date_str = end_date

if end_date_str == "today":
    download_date = dt.datetime.today()
else:
    download_date = dt.datetime.strptime(end_date_str, "%Y-%m-%d")
download_date_str = download_date.strftime("%Y-%m-%d")
if download:
    usempl_df, beg_date_str2, end_date_str2 = get_payems_data(
        beg_date_str=beg_date_str,
        end_date_str=end_date_str,
        file_path=None
    )
    print(
        "PAYEMS data downloaded on " +  download_date_str +
        " and has most recent PAYEMS data month of " + end_date_str2 + "."
    )
else:
    usempl_df, beg_date_str2, end_date_str2 = get_payems_data(
        beg_date_str=beg_date_str,
        end_date_str=end_date_str,
        file_path=os.path.join(data_dir, "usempl_" + end_date_str + ".csv")
    )
    print(
        "PAYEMS data loaded from memory on " +  download_date_str +
        " and has most recent PAYEMS data month of " + end_date_str2 + "."
    )
# Out:
# Beginning date of U.S. employment series is 1919-07-01
# End date of U.S. employment series is 2024-03-01
# PAYEMS data downloaded on 2024-04-25 and has most recent PAYEMS data month of 2024-03-01.

# %%
# Create numerical date column month number that is the index
usempl_df["Month_num"] = usempl_df.index

# reorder the columns
usempl_df = usempl_df[
    [
        "Date",
        "Month_num",
        "PAYEMS",
        "BLS_annual",
        "diff_monthly",
        "diff_yoy",
        "Source",
    ]
]

# Create a dataframe that only contains dates less than 1939-01-01
usempl_imputed_df = usempl_df[usempl_df['Date'] < '1939-01-01']
usempl_monthly_df = usempl_df[usempl_df['Date'] >= '1939-01-01']
# Create a dataframe usempl_annual_df that only contains data from before
# 1939 and only for month 7
usempl_annual_df = usempl_imputed_df[
    usempl_imputed_df['Date'].dt.month == 7
]
usempl_imputed_cds = ColumnDataSource(usempl_imputed_df)
usempl_annual_cds = ColumnDataSource(usempl_annual_df)
usempl_monthly_cds = ColumnDataSource(usempl_monthly_df)
usempl_cds = ColumnDataSource(usempl_df)
print(usempl_imputed_df)
print(usempl_annual_df)
print(usempl_monthly_df)
usempl_df.to_csv(os.path.join(data_dir, "junk.csv"))
# Out:
#           Date  Month_num        PAYEMS  BLS_annual   diff_monthly  \
# 0   1919-07-01          0  2.707800e+07  27078000.0            NaN
# 1   1919-08-01          1  2.747546e+07         NaN  397457.629359
# 2   1919-09-01          2  2.778468e+07         NaN  309221.098029
# 3   1919-10-01          3  2.801165e+07         NaN  226966.928133
# 4   1919-11-01          4  2.816234e+07         NaN  150695.119670
# ..         ...        ...           ...         ...            ...
# 229 1938-08-01        229  2.921868e+07         NaN   24675.652871
# 230 1938-09-01        230  2.929733e+07         NaN   78653.789052
# 231 1938-10-01        231  2.941853e+07         NaN  121195.627236
# 232 1938-11-01        232  2.957083e+07         NaN  152301.167423
# 233 1938-12-01        233  2.974280e+07         NaN  171970.409613
#
#          diff_yoy                                   Source
# 0             NaN  Cubic spline interp. of BLS annual data
# 1             NaN  Cubic spline interp. of BLS annual data
# 2             NaN  Cubic spline interp. of BLS annual data
# 3             NaN  Cubic spline interp. of BLS annual data
# 4             NaN  Cubic spline interp. of BLS annual data
# ..            ...                                      ...
# 229 -1.715437e+06  Cubic spline interp. of BLS annual data
# 230 -1.512012e+06  Cubic spline interp. of BLS annual data
# 231 -1.228462e+06  Cubic spline interp. of BLS annual data
# 232 -8.865226e+05  Cubic spline interp. of BLS annual data
# 233 -5.079298e+05  Cubic spline interp. of BLS annual data
#
# [234 rows x 7 columns]
#           Date  Month_num      PAYEMS  BLS_annual   diff_monthly   diff_yoy  \
# 0   1919-07-01          0  27078000.0  27078000.0            NaN        NaN
# 12  1920-07-01         12  27340000.0  27340000.0 -244114.336401   262000.0
# 24  1921-07-01         24  24372000.0  24372000.0 -118445.148418 -2968000.0
# 36  1922-07-01         36  25816000.0  25816000.0  249400.717112  1444000.0
# 48  1923-07-01         48  28382000.0  28382000.0   98063.344786  2566000.0
# 60  1924-07-01         60  28028000.0  28028000.0  -30159.883293  -354000.0
# 72  1925-07-01         72  28786000.0  28786000.0  102742.855053   758000.0
# 84  1926-07-01         84  29806000.0  29806000.0   57738.231600  1020000.0
# 96  1927-07-01         96  29962000.0  29962000.0  -22347.401823   156000.0
# 108 1928-07-01        108  29986000.0  29986000.0   79824.986804    24000.0
# 120 1929-07-01        120  31324000.0  31324000.0   17009.260162  1338000.0
# 132 1930-07-01        132  29409000.0  29409000.0 -226984.133935 -1915000.0
# 144 1931-07-01        144  26635000.0  26635000.0 -262041.474422 -2774000.0
# 156 1932-07-01        156  23615000.0  23615000.0 -167870.223007 -3020000.0
# 168 1933-07-01        168  23699000.0  23699000.0  136794.357189    84000.0
# 180 1934-07-01        180  25940000.0  25940000.0  156457.261842  2241000.0
# 192 1935-07-01        192  27039000.0  27039000.0   94259.118592  1099000.0
# 204 1936-07-01        204  29068000.0  29068000.0  230330.337865  2029000.0
# 216 1937-07-01        216  31011000.0  31011000.0  -21376.766347  1943000.0
# 228 1938-07-01        228  29194000.0  29194000.0  -37116.096552 -1817000.0
#
#                                       Source
# 0    Cubic spline interp. of BLS annual data
# 12   Cubic spline interp. of BLS annual data
# 24   Cubic spline interp. of BLS annual data
# 36   Cubic spline interp. of BLS annual data
# 48   Cubic spline interp. of BLS annual data
# 60   Cubic spline interp. of BLS annual data
# 72   Cubic spline interp. of BLS annual data
# 84   Cubic spline interp. of BLS annual data
# 96   Cubic spline interp. of BLS annual data
# 108  Cubic spline interp. of BLS annual data
# 120  Cubic spline interp. of BLS annual data
# 132  Cubic spline interp. of BLS annual data
# 144  Cubic spline interp. of BLS annual data
# 156  Cubic spline interp. of BLS annual data
# 168  Cubic spline interp. of BLS annual data
# 180  Cubic spline interp. of BLS annual data
# 192  Cubic spline interp. of BLS annual data
# 204  Cubic spline interp. of BLS annual data
# 216  Cubic spline interp. of BLS annual data
# 228  Cubic spline interp. of BLS annual data
#            Date  Month_num       PAYEMS  BLS_annual   diff_monthly  \
# 234  1939-01-01        234   29923000.0         NaN  180203.353805
# 235  1939-02-01        235   30100000.0         NaN  177000.000000
# 236  1939-03-01        236   30280000.0         NaN  180000.000000
# 237  1939-04-01        237   30094000.0         NaN -186000.000000
# 238  1939-05-01        238   30299000.0         NaN  205000.000000
# ...         ...        ...          ...         ...            ...
# 1252 2023-11-01       1252  157014000.0         NaN  182000.000000
# 1253 2023-12-01       1253  157304000.0         NaN  290000.000000
# 1254 2024-01-01       1254  157560000.0         NaN  256000.000000
# 1255 2024-02-01       1255  157830000.0         NaN  270000.000000
# 1256 2024-03-01       1256  158133000.0         NaN  303000.000000
#
#           diff_yoy              Source
# 234  -1.144197e+05  BLS monthly series
# 235   2.722714e+05  BLS monthly series
# 236   6.480471e+05  BLS monthly series
# 237   6.336076e+05  BLS monthly series
# 238   9.756532e+05  BLS monthly series
# ...            ...                 ...
# 1252  2.859000e+06  BLS monthly series
# 1253  3.013000e+06  BLS monthly series
# 1254  2.787000e+06  BLS monthly series
# 1255  2.770000e+06  BLS monthly series
# 1256  2.927000e+06  BLS monthly series
#
# [1023 rows x 7 columns]

# %%
# Create recession data column data source object
recession_df = pd.read_csv(
    recession_data_path, parse_dates=['Peak','Trough']
)
recession_data_length = len(recession_df['Peak'])

# %%
# Create Bokeh plot of PAYEMS time series
fig_title = fig_title_str
filename = "tseries_payems_" + end_date_str2 + ".html"
output_file(os.path.join(image_dir, filename), title=fig_title, mode='inline')

# Format the tooltip
tooltips = [
    ("Date", "@Date{%F}"),
    ("Employment", "@PAYEMS{0,0.}"),
    ("Monthly change", "@diff_monthly{0,0.}"),
    ("Year-over-year change", "@diff_yoy{0,0.}")
]

min_date = usempl_df['Date'].min()
max_date = usempl_df['Date'].max()
min_y_val = usempl_df['PAYEMS'].min()
max_y_val = usempl_df['PAYEMS'].max()
range_y_vals = max_y_val - min_y_val
fig_buffer_pct = 0.10
fig = figure(
    height=400,
    width=800,
    x_axis_label="Date (months)",
    y_axis_label="US nonfarm payroll employment",
    y_range=(
        min_y_val - fig_buffer_pct * range_y_vals,
        max_y_val + fig_buffer_pct * range_y_vals,
    ),
    # x_range=(
    #     (-bkwd_mths_main - fig_buffer_pct * datarange_main_mths),
    #     (frwd_mths_main + fig_buffer_pct * datarange_main_mths),
    # ),
    tools=[
        "save",
        "zoom_in",
        "zoom_out",
        "box_zoom",
        "pan",
        "undo",
        "redo",
        "reset",
        "hover",
        "help",
    ],
    toolbar_location="left",
)
fig.toolbar.logo = None

# Set title font size and axes font sizes
fig.title.text_font_size = '18pt'
fig.xaxis.axis_label_text_font_size = '12pt'
fig.xaxis.major_label_text_font_size = '12pt'
fig.yaxis.axis_label_text_font_size = '12pt'
fig.yaxis.major_label_text_font_size = '12pt'

# # Modify tick intervals for X-axis and Y-axis
# fig.xaxis.ticker = SingleIntervalTicker(interval=10, num_minor_ticks=2)
# fig.xgrid.ticker = SingleIntervalTicker(interval=10)
# fig.yaxis.ticker = SingleIntervalTicker(interval=5, num_minor_ticks=5)
# fig.ygrid.ticker = SingleIntervalTicker(interval=5)

# if recession_bars:
#     # Create recession bars
#     for x in range(0, recession_data_length):
#         peak_date = recession_df["Peak"][x]
#         trough_date = recession_df["Trough"][x]
#         if peak_date >= min_date and trough_date >= min_date:
#             fig.patch(
#                 x=[peak_date, trough_date, trough_date, peak_date],
#                 y=[-100, -100, max_y_val + 10, max_y_val + 10],
#                 fill_color="gray",
#                 fill_alpha=0.4,
#                 line_width=0,
#                 legend_label="Recession",
#             )
#         if (
#             peak_date == trough_date
#             and peak_date >= min_date
#             and trough_date >= min_date
#         ):
#             fig.patch(
#                 x=[peak_date, trough_date + 1, trough_date + 1, peak_date],
#                 y=[-100, -100, max_y_val + 10, max_y_val + 10],
#                 fill_color="gray",
#                 fill_alpha=0.4,
#                 line_width=0,
#                 legend_label="Recession",
#             )

fig.line(
    x='Month_num',
    y="PAYEMS",
    source=usempl_imputed_cds,
    color='blue',
    line_dash='dashed',
    line_width=3,
    alpha=0.7,
    muted_alpha=0.2,
    legend_label='Interpolated from annual data'
)
fig.scatter(
    x='Month_num',
    y="PAYEMS",
    source=usempl_annual_cds,
    size=3,
    line_width=1,
    line_color='black',
    fill_color='purple',
    alpha=0.7,
    muted_alpha=0.2,
    legend_label='Annual data points'
)
fig.line(
    x='Month_num',
    y="PAYEMS",
    source=usempl_monthly_cds,
    color='blue',
    line_dash='solid',
    line_width=3,
    alpha=0.7,
    muted_alpha=0.2,
    legend_label='Monthly data'
)

# Add legend
fig.legend.location = 'top_left'
fig.legend.border_line_width = 2
fig.legend.border_line_color = 'black'
fig.legend.border_line_alpha = 1
fig.legend.label_text_font_size = '4mm'

# Set legend muting click policy
fig.legend.click_policy = 'mute'

# Add notes below image. The list note_text_list contains a tuple with a
# string for every line of the notes
updated_date_str = (
    download_date.strftime("%B") +
    " " +
    download_date.strftime("%d").lstrip("0") +
    ", " +
    download_date.strftime("%Y")
)
note_text_list = [
    (
        "Source: Richard W. Evans (@RickEcon), " +
        "historical PAYEMS data from FRED and BLS, " +
        "updated " +
        updated_date_str +
        "."
    )
]
for note_text in note_text_list:
    caption = Title(text=note_text, align='left', text_font_size='4mm',
                    text_font_style='italic')
    fig.add_layout(caption, 'below')

if html_show:
    show(fig)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 159
#     156     fig.add_layout(caption, 'below')
#     158 if html_show:
# --> 159     show(fig)
#
# File /opt/anaconda3/envs/usempl-plots-dev/lib/python3.12/site-packages/bokeh/io/showing.py:149, in show(obj, browser, new, notebook_handle, notebook_url, **kwargs)
#     146 state = curstate()
#     148 if isinstance(obj, UIElement):
# --> 149     return _show_with_state(obj, state, browser, new, notebook_handle=notebook_handle)
#     151 def is_application(obj: Any) -> TypeGuard[Application]:
#     152     return getattr(obj, '_is_a_bokeh_application_class', False)
#
# File /opt/anaconda3/envs/usempl-plots-dev/lib/python3.12/site-packages/bokeh/io/showing.py:200, in _show_with_state(obj, state, browser, new, notebook_handle)
#     197     shown = True
#     199 if state.file or not shown:
# --> 200     _show_file_with_state(obj, state, new, controller)
#     202 return comms_handle
#
# File /opt/anaconda3/envs/usempl-plots-dev/lib/python3.12/site-packages/bokeh/io/showing.py:181, in _show_file_with_state(obj, state, new, controller)
#     177 def _show_file_with_state(obj: UIElement, state: State, new: BrowserTarget, controller: BrowserLike) -> None:
#     178     '''
#     179
#     180     '''
# --> 181     filename = save(obj, state=state)
#     182     controller.open("file://" + filename, new=NEW_PARAM[new])
#
# File /opt/anaconda3/envs/usempl-plots-dev/lib/python3.12/site-packages/bokeh/io/saving.py:98, in save(obj, filename, resources, title, template, state)
#      95 theme = state.document.theme
#      97 filename, resources, title = _get_save_args(state, filename, resources, title)
# ---> 98 _save_helper(obj, filename, resources, title, template, theme)
#      99 return abspath(expanduser(filename))
#
# File /opt/anaconda3/envs/usempl-plots-dev/lib/python3.12/site-packages/bokeh/io/saving.py:164, in _save_helper(obj, filename, resources, title, template, theme)
#     160 '''
#     161
#     162 '''
#     163 from ..embed import file_html
# --> 164 html = file_html(obj, resources=resources, title=title, template=template or FILE, theme=theme)
#     166 with open(filename, mode="w", encoding="utf-8") as f:
#     167     f.write(html)
#
# File /opt/anaconda3/envs/usempl-plots-dev/lib/python3.12/site-packages/bokeh/embed/standalone.py:358, in file_html(models, resources, title, template, template_variables, theme, suppress_callback_warning, _always_new)
#     354     models_seq = models
#     356 resources = Resources.build(resources)
# --> 358 with OutputDocumentFor(models_seq, apply_theme=theme, always_new=_always_new) as doc:
#     359     (docs_json, render_items) = standalone_docs_json_and_render_items(models_seq, suppress_callback_warning=suppress_callback_warning)
#     360     title = _title_from_models(models_seq, title)
#
# File /opt/anaconda3/envs/usempl-plots-dev/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File /opt/anaconda3/envs/usempl-plots-dev/lib/python3.12/site-packages/bokeh/embed/util.py:153, in OutputDocumentFor(objs, apply_theme, always_new)
#     151     doc = _new_doc()
#     152     for model in objs:
# --> 153         doc.add_root(model)
#     155 # handle a single shared document
#     156 elif len(docs) == 1:
#
# File /opt/anaconda3/envs/usempl-plots-dev/lib/python3.12/site-packages/bokeh/document/document.py:321, in Document.add_root(self, model, setter)
#     318 if model in self._roots:
#     319     return
# --> 321 with self.models.freeze():
#     322     self._roots.append(model)
#     324 self.callbacks.trigger_on_change(RootAddedEvent(self, model, setter))
#
# File /opt/anaconda3/envs/usempl-plots-dev/lib/python3.12/contextlib.py:144, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     142 if typ is None:
#     143     try:
# --> 144         next(self.gen)
#     145     except StopIteration:
#     146         return False
#
# File /opt/anaconda3/envs/usempl-plots-dev/lib/python3.12/site-packages/bokeh/document/models.py:135, in DocumentModelManager.freeze(self)
#     133 self._push_freeze()
#     134 yield
# --> 135 self._pop_freeze()
#
# File /opt/anaconda3/envs/usempl-plots-dev/lib/python3.12/site-packages/bokeh/document/models.py:288, in DocumentModelManager._pop_freeze(self)
#     286 self._freeze_count -= 1
#     287 if self._freeze_count == 0:
# --> 288     self.recompute()
#
# File /opt/anaconda3/envs/usempl-plots-dev/lib/python3.12/site-packages/bokeh/document/models.py:235, in DocumentModelManager.recompute(self)
#     232     md._detach_document()
#     234 for ma in to_attach:
# --> 235     ma._attach_document(document)
#     236     self._new_models.add(ma)
#     238 self._models = recomputed
#
# File /opt/anaconda3/envs/usempl-plots-dev/lib/python3.12/site-packages/bokeh/model/model.py:584, in Model._attach_document(self, doc)
#     581     return
#     583 if self.document is not None:
# --> 584     raise RuntimeError(f"Models must be owned by only a single document, {self!r} is already in a doc")
#     586 doc.theme.apply_to_model(self)
#     587 self.document = doc
#
# RuntimeError: Models must be owned by only a single document, Selection(id='p1008', ...) is already in a doc

# %%
if recession_bars:
    # Create recession bars
    for x in range(0, recession_data_length):
        peak_date = recession_df['Peak'][x]
        trough_date = recession_df['Trough'][x]
        if(peak_date >= min_date and trough_date >= min_date):
            fig.patch(
                x=[peak_date, trough_date, trough_date, peak_date],
                y=[-100, -100, max_y_val+ 10, max_y_val + 10],
                fill_color='gray',
                fill_alpha=0.4,
                line_width=0,
                legend_label='Recession'
            )
        if (
            peak_date == trough_date and
            peak_date >= min_date and
            trough_date >= min_date
        ):
            fig.patch(
                x=[peak_date, trough_date + 1, trough_date + 1, peak_date],
                y=[-100, -100, max_y_val + 10, max_y_val + 10],
                fill_color='gray',
                fill_alpha=0.4,
                line_width=0,
                legend_label='Recession'
            )
